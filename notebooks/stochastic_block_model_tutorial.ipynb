# %% [markdown]
# ### Stochastic Block Models
#
# I gave ChatGPT the paper by Holland et al. and the paper by Girvan-Newman, and asked for a summary of the differences. Here's what it came up with.

# %% [markdown]
# | Feature                         | Stochastic Block Model (SBM)          | Girvan-Newman Network Formation Model |
# |---------------------------------|--------------------------------------|--------------------------------------|
# | **Generative Process**         | Nodes are assigned to communities in advance | Network structure emerges from preferential attachment |
# | **Edge Probability**           | Based only on group membership       | Based on assortative mixing, linking nodes with similar attributes |
# | **Fixed vs. Dynamic**          | Static model: All nodes exist at the start, edges are drawn probabilistically | Growth model: Nodes and edges are added over time |
# | **Flexibility**                | Assumes block structure; works well for well-separated communities | Can produce overlapping and evolving community structures |
# | **Assortativity**              | Can incorporate assortativity but is not its primary feature | Explicitly models assortative mixing in real-world networks |
#
# Let's discuss each

# %% [markdown]
# ---

# %% [markdown]
# ### Holland, Laskey, Leinhardt Stochastic Block Model
#
# This algorithm defines
# - a set of groups
# - the number of nodes within each group
# - the probability of an edge between nodes for each group pair, denoted by p[i,j] for groups i and j
#
# The algorithm is very straightforward.
# - create a graph with nodes assigned to each group
# - create the set of all possible edges
# - for each possible edge
#   - if the possible edge is between nodes in group i and group j AND
#       - add the edge to the graph if a random number is less than p[i,j]
#
# We can implement this for an undirected graph with no self-loops.

# %%
############
## Cell 1 ##
############

import networkx as nx
from drawing_utilities import show_partitions
from drawing_utilities import show_dendrogram
from drawing_utilities import show_graph
from drawing_utilities import show_partitions_with_scaled_nodesize


def generate_holland_stochastic_block_graph(print_p: bool = False) -> nx.Graph:
    nodes_per_group: list[int] = [30, 20, 25]
    p: list[list[float]] = [[0.2, 0.01, 0.05],
                            [0.01, 0.3, 0.01],
                            [0.05, 0.01, 0.2]]
    if print_p:
        row_label_width: int = 4
        column_width: int = 8
        header: str = f"{'':<{row_label_width}}" + "".join(
            f"g{group_index:<{column_width - 1}}" for group_index in range(len(p))
        )
        print("Probability matrix p:")
        print(header)
        for row_index, row in enumerate(p):
            formatted_row: str = "".join(f"{value:<{column_width}.2f}" for value in row)
            print(f"g{row_index:<{row_label_width - 1}}{formatted_row}")
    return nx.stochastic_block_model(nodes_per_group, p, seed=42)

# %%
############
## Cell 2 ##
############
G = generate_holland_stochastic_block_graph(print_p=True)
show_graph(G, title = "Holland Stochastic Block Model")
# Out:
# Probability matrix p:
#     g0      g1      g2
# g0  0.20    0.01    0.05
# g1  0.01    0.30    0.01
# g2  0.05    0.01    0.20

# %%
############
## Cell 3 ##
############
partitions = nx.community.louvain_communities(G, seed=42)
show_partitions(G, partition=partitions, title="Louvain Communities of Holland Stochastic Block Model:\n")

# %%
############
## Cell 4 ##
############
show_dendrogram(G, title="Holland Stochastic Block Model",height_metric="max_cluster")

# %% [markdown]
# The algorithm is very straightforward. I'll write my code to emphasize teaching rather than code efficiency. Let's start by writing a loop that iterates through each possible pairing of groups and generates all possible edges. I'll do this for small graphs so that we can see the pattern.

# %%
############
## Cell 5 ##
############

from itertools import combinations_with_replacement
import random

def create_node_groups(nodes_per_group: list[int]) -> dict[int, set[int]]:
    node_groups: dict[int, set[int]] = dict()
    start_node = 0

    for group_index in range(len(nodes_per_group)):
        group_size = nodes_per_group[group_index]
        group = set(range(start_node, start_node + group_size))
        node_groups[group_index] = group
        start_node += group_size

    return node_groups

nodes_per_group: list[int] = [4,4,5]
node_groups: dict[int, list[int]] = create_node_groups(nodes_per_group)
print(node_groups)
# Out:
# {0: {0, 1, 2, 3}, 1: {4, 5, 6, 7}, 2: {8, 9, 10, 11, 12}}

# %%
############
## Cell 6 ##
############
G: nx.Graph = nx.Graph()
nx.Graph.add_nodes_from(G,list(range(sum(nodes_per_group))))
true_partition: tuple[set[int]] = [group for  group in node_groups.values()]
show_partitions(G, partition=true_partition, title=f"Graph has {len(G)} nodes:\n")

# %%
############
## Cell 7 ##
############
prob_edge: list[list[int, int]] = [[0.2, 0.01, 0.02],
                            [0.01, 0.3, 0.01],
                            [0.02, 0.01, 0.2]]
random_number_generator: random.Random = random.Random()
random_number_generator.seed(1234)
for i,j in combinations_with_replacement(range(len(nodes_per_group)), 2):
    print(f"edges between group {i} and group {j}")
    edges: list[tuple[int, int]] = []
    for node1 in true_partition[i]:
        for node2 in true_partition[j]:
            edges.append((node1, node2))
    print(f"\t edge candidates: {edges}")
    print(f"\tp = {prob_edge[i][j]}")
    for edge in edges:
        r: float = random_number_generator.uniform(0,1)
        if r < prob_edge[i][j]:
            print(f"\t\t add edge {edge}? yes since r = {r} < p = {prob_edge[i][j]}")
            G.add_edge(edge[0], edge[1]) 
        else:
            print(f"\t\t add edge {edge}? no since r = {r} > p = {prob_edge[i][j]}")
# Out:
# edges between group 0 and group 0
# 	 edge candidates: [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3), (3, 0), (3, 1), (3, 2), (3, 3)]
# 	p = 0.2
# 		 add edge (0, 0)? no since r = 0.9664535356921388 > p = 0.2
# 		 add edge (0, 1)? no since r = 0.4407325991753527 > p = 0.2
# 		 add edge (0, 2)? yes since r = 0.007491470058587191 < p = 0.2
# 		 add edge (0, 3)? no since r = 0.9109759624491242 > p = 0.2
# 		 add edge (1, 0)? no since r = 0.939268997363764 > p = 0.2
# 		 add edge (1, 1)? no since r = 0.5822275730589491 > p = 0.2
# 		 add edge (1, 2)? no since r = 0.6715634814879851 > p = 0.2
# 		 add edge (1, 3)? yes since r = 0.08393822683708396 < p = 0.2
# 		 add edge (2, 0)? no since r = 0.7664809327917963 > p = 0.2
# 		 add edge (2, 1)? no since r = 0.23680977536311776 > p = 0.2
# 		 add edge (2, 2)? yes since r = 0.030814021726609964 < p = 0.2
# 		 add edge (2, 3)? no since r = 0.7887727172362835 > p = 0.2
# 		 add edge (3, 0)? no since r = 0.3460889655971231 > p = 0.2
# 		 add edge (3, 1)? no since r = 0.6232814750391685 > p = 0.2
# 		 add edge (3, 2)? no since r = 0.6158156951036152 > p = 0.2
# 		 add edge (3, 3)? yes since r = 0.14855463870828756 < p = 0.2
# edges between group 0 and group 1
# 	 edge candidates: [(0, 4), (0, 5), (0, 6), (0, 7), (1, 4), (1, 5), (1, 6), (1, 7), (2, 4), (2, 5), (2, 6), (2, 7), (3, 4), (3, 5), (3, 6), (3, 7)]
# 	p = 0.01
# 		 add edge (0, 4)? no since r = 0.18309064740993164 > p = 0.01
# 		 add edge (0, 5)? no since r = 0.11441296968868764 > p = 0.01
# 		 add edge (0, 6)? no since r = 0.014618780486909122 > p = 0.01
# 		 add edge (0, 7)? no since r = 0.48675154060475834 > p = 0.01
# 		 add edge (1, 4)? no since r = 0.9649015609162157 > p = 0.01
# 		 add edge (1, 5)? no since r = 0.06456228097718608 > p = 0.01
# 		 add edge (1, 6)? no since r = 0.5410881855511303 > p = 0.01
# 		 add edge (1, 7)? no since r = 0.46589855900830957 > p = 0.01
# 		 add edge (2, 4)? no since r = 0.6014634495610515 > p = 0.01
# 		 add edge (2, 5)? no since r = 0.08892882999066232 > p = 0.01
# 		 add edge (2, 6)? no since r = 0.5790026861873665 > p = 0.01
# 		 add edge (2, 7)? no since r = 0.26958550381944824 > p = 0.01
# 		 add edge (3, 4)? no since r = 0.5564325605562156 > p = 0.01
# 		 add edge (3, 5)? no since r = 0.6446342341782827 > p = 0.01
# 		 add edge (3, 6)? no since r = 0.48103637136651844 > p = 0.01
# 		 add edge (3, 7)? no since r = 0.35523914744298335 > p = 0.01
# edges between group 0 and group 2
# 	 edge candidates: [(0, 8), (0, 9), (0, 10), (0, 11), (0, 12), (1, 8), (1, 9), (1, 10), (1, 11), (1, 12), (2, 8), (2, 9), (2, 10), (2, 11), (2, 12), (3, 8), (3, 9), (3, 10), (3, 11), (3, 12)]
# 	p = 0.02
# 		 add edge (0, 8)? no since r = 0.249152121361209 > p = 0.02
# 		 add edge (0, 9)? no since r = 0.9335154980423467 > p = 0.02
# 		 add edge (0, 10)? no since r = 0.45338801947649354 > p = 0.02
# 		 add edge (0, 11)? no since r = 0.5301612069115903 > p = 0.02
# 		 add edge (0, 12)? yes since r = 0.019299566309716853 < p = 0.02
# 		 add edge (1, 8)? no since r = 0.5081019257797922 > p = 0.02
# 		 add edge (1, 9)? yes since r = 0.005780237417743139 < p = 0.02
# 		 add edge (1, 10)? no since r = 0.14376842759559538 > p = 0.02
# 		 add edge (1, 11)? no since r = 0.47282692534740633 > p = 0.02
# 		 add edge (1, 12)? no since r = 0.3773474407725964 > p = 0.02
# 		 add edge (2, 8)? no since r = 0.05417519864614284 > p = 0.02
# 		 add edge (2, 9)? no since r = 0.5875285081310694 > p = 0.02
# 		 add edge (2, 10)? no since r = 0.1640032237419612 > p = 0.02
# 		 add edge (2, 11)? no since r = 0.5573302374414681 > p = 0.02
# 		 add edge (2, 12)? no since r = 0.1442457216019083 > p = 0.02
# 		 add edge (3, 8)? no since r = 0.9373070846962247 > p = 0.02
# 		 add edge (3, 9)? no since r = 0.7709799715197749 > p = 0.02
# 		 add edge (3, 10)? no since r = 0.9569331223494054 > p = 0.02
# 		 add edge (3, 11)? no since r = 0.14122776441649953 > p = 0.02
# 		 add edge (3, 12)? no since r = 0.3053927082876986 > p = 0.02
# edges between group 1 and group 1
# 	 edge candidates: [(4, 4), (4, 5), (4, 6), (4, 7), (5, 4), (5, 5), (5, 6), (5, 7), (6, 4), (6, 5), (6, 6), (6, 7), (7, 4), (7, 5), (7, 6), (7, 7)]
# 	p = 0.3
# 		 add edge (4, 4)? yes since r = 0.03958962422796164 < p = 0.3
# 		 add edge (4, 5)? yes since r = 0.27678369479169207 < p = 0.3
# 		 add edge (4, 6)? no since r = 0.8065125051156038 > p = 0.3
# 		 add edge (4, 7)? yes since r = 0.177343035278254 < p = 0.3
# 		 add edge (5, 4)? yes since r = 0.15457051471078964 < p = 0.3
# 		 add edge (5, 5)? no since r = 0.9547186557023949 > p = 0.3
# 		 add edge (5, 6)? yes since r = 0.154551400089043 < p = 0.3
# 		 add edge (5, 7)? no since r = 0.8338892941512318 > p = 0.3
# 		 add edge (6, 4)? yes since r = 0.04106280627180747 < p = 0.3
# 		 add edge (6, 5)? no since r = 0.38618352833582825 > p = 0.3
# 		 add edge (6, 6)? no since r = 0.3495923019636925 > p = 0.3
# 		 add edge (6, 7)? no since r = 0.3417077927504538 > p = 0.3
# 		 add edge (7, 4)? no since r = 0.8164630567142304 > p = 0.3
# 		 add edge (7, 5)? no since r = 0.47593490813172823 > p = 0.3
# 		 add edge (7, 6)? no since r = 0.7828902895224036 > p = 0.3
# 		 add edge (7, 7)? no since r = 0.4708401253088451 > p = 0.3
# edges between group 1 and group 2
# 	 edge candidates: [(4, 8), (4, 9), (4, 10), (4, 11), (4, 12), (5, 8), (5, 9), (5, 10), (5, 11), (5, 12), (6, 8), (6, 9), (6, 10), (6, 11), (6, 12), (7, 8), (7, 9), (7, 10), (7, 11), (7, 12)]
# 	p = 0.01
# 		 add edge (4, 8)? no since r = 0.8173440068581418 > p = 0.01
# 		 add edge (4, 9)? no since r = 0.8815675986556064 > p = 0.01
# 		 add edge (4, 10)? no since r = 0.43959639767963965 > p = 0.01
# 		 add edge (4, 11)? no since r = 0.781063597792481 > p = 0.01
# 		 add edge (4, 12)? no since r = 0.8147411602576974 > p = 0.01
# 		 add edge (5, 8)? no since r = 0.29567891564250737 > p = 0.01
# 		 add edge (5, 9)? no since r = 0.12387667430690597 > p = 0.01
# 		 add edge (5, 10)? no since r = 0.18562186074498854 > p = 0.01
# 		 add edge (5, 11)? no since r = 0.4360597935994146 > p = 0.01
# 		 add edge (5, 12)? no since r = 0.11946740701121195 > p = 0.01
# 		 add edge (6, 8)? no since r = 0.5297991417578831 > p = 0.01
# 		 add edge (6, 9)? no since r = 0.8294211614174424 > p = 0.01
# 		 add edge (6, 10)? no since r = 0.48520115298643485 > p = 0.01
# 		 add edge (6, 11)? no since r = 0.817734001701804 > p = 0.01
# 		 add edge (6, 12)? no since r = 0.6563916225394183 > p = 0.01
# 		 add edge (7, 8)? no since r = 0.6410430311516905 > p = 0.01
# 		 add edge (7, 9)? no since r = 0.3453489252042602 > p = 0.01
# 		 add edge (7, 10)? no since r = 0.7026589490483248 > p = 0.01
# 		 add edge (7, 11)? no since r = 0.8099405837312028 > p = 0.01
# 		 add edge (7, 12)? no since r = 0.15716958478401755 > p = 0.01
# edges between group 2 and group 2
# 	 edge candidates: [(8, 8), (8, 9), (8, 10), (8, 11), (8, 12), (9, 8), (9, 9), (9, 10), (9, 11), (9, 12), (10, 8), (10, 9), (10, 10), (10, 11), (10, 12), (11, 8), (11, 9), (11, 10), (11, 11), (11, 12), (12, 8), (12, 9), (12, 10), (12, 11), (12, 12)]
# 	p = 0.2
# 		 add edge (8, 8)? no since r = 0.9079906191155508 > p = 0.2
# 		 add edge (8, 9)? no since r = 0.26933036723681814 > p = 0.2
# 		 add edge (8, 10)? yes since r = 0.15484649574701626 < p = 0.2
# 		 add edge (8, 11)? no since r = 0.8404791651944925 > p = 0.2
# 		 add edge (8, 12)? no since r = 0.7201279798410062 > p = 0.2
# 		 add edge (9, 8)? no since r = 0.7935623957737522 > p = 0.2
# 		 add edge (9, 9)? no since r = 0.4466706642559476 > p = 0.2
# 		 add edge (9, 10)? yes since r = 0.07077388523885675 < p = 0.2
# 		 add edge (9, 11)? no since r = 0.3952430502634495 > p = 0.2
# 		 add edge (9, 12)? yes since r = 0.04773529540398547 < p = 0.2
# 		 add edge (10, 8)? no since r = 0.28613350393922754 > p = 0.2
# 		 add edge (10, 9)? yes since r = 0.037994595016476396 < p = 0.2
# 		 add edge (10, 10)? no since r = 0.5067148419441442 > p = 0.2
# 		 add edge (10, 11)? yes since r = 0.08766779894229271 < p = 0.2
# 		 add edge (10, 12)? no since r = 0.9328256468398046 > p = 0.2
# 		 add edge (11, 8)? no since r = 0.6993872895717961 > p = 0.2
# 		 add edge (11, 9)? no since r = 0.31698602665681064 > p = 0.2
# 		 add edge (11, 10)? no since r = 0.9450510700109166 > p = 0.2
# 		 add edge (11, 11)? yes since r = 0.06622760433688513 < p = 0.2
# 		 add edge (11, 12)? no since r = 0.2574288908876978 > p = 0.2
# 		 add edge (12, 8)? yes since r = 0.07299964643145462 < p = 0.2
# 		 add edge (12, 9)? no since r = 0.4263042580299481 > p = 0.2
# 		 add edge (12, 10)? no since r = 0.2018967725432862 > p = 0.2
# 		 add edge (12, 11)? no since r = 0.39664663519413834 > p = 0.2
# 		 add edge (12, 12)? no since r = 0.7048599115494352 > p = 0.2

# %% [markdown]
# Show true groups

# %%
############
## Cell 8 ##
############
show_partitions(G, partition=true_partition, title="True Groups for Holland Stochastic Graph:\n")

# %% [markdown]
# Show groups found by Louvain partition

# %%
############
## Cell 9 ##
############

partition: list[set[int]] = nx.community.louvain_communities(G,seed = 42)
show_partitions(G, partition=partition, title = "Louvain Partition of Holland Stochastic Block Model:")

# %% [markdown]
# More nodes

# %%
nodes_per_group = [20, 20, 25]
node_groups: dict[int, list[int]] = create_node_groups(nodes_per_group)
true_partition: tuple[set[int]] = [group for  group in node_groups.values()]
G = nx.stochastic_block_model(nodes_per_group, prob_edge, seed=42)
partition: list[set[int]] = nx.community.louvain_communities(G,seed = 42)
show_partitions(G, partition=true_partition, title = "Partition of Holland Stochastic Block Model:")
num_edges: int = len(G.edges())
print(f"Num Edges = {num_edges}")
# Out:
# Num Edges = 176

# %% [markdown]
# ---

# %% [markdown]
# #### Is Holland's Model Assortative (in Degree)?

# %%
import matplotlib.pyplot as plt
import numpy as np


def show_degree_vs_neighbor_degree(G: nx.Graph, 
                                   title_prefix: str = "") -> None:
    degree = dict(G.degree())

    # Compute average neighbor degree
    avg_neighbor_degree = nx.average_neighbor_degree(G)

    # Scatter plot: degree vs. average neighbor degree
    plt.figure(figsize=(8, 6))
    plt.scatter(degree.values(), avg_neighbor_degree.values(), alpha=0.7)
    plt.xscale("log")
    plt.yscale("log")
    plt.xlabel("Node Degree")
    plt.ylabel("Average Neighbor Degree")
    title: str = title_prefix + f"Node Degree vs. Average Neighbor Degree:\nAssortativity = {np.round(nx.degree_assortativity_coefficient(G),2)}"
    plt.title(title)
    plt.grid(True)
    plt.show()

# %%
show_degree_vs_neighbor_degree(G, title_prefix="Holland Model: ")

# %% [markdown]
# Show plot with node size proportional do degree

# %%
show_partitions_with_scaled_nodesize(G, true_partition, title="Louvain Partition of Holland Stochastic Block Model:\n")

# %% [markdown]
# ---

# %% [markdown]
# ### Girvan-Newman Stochastic Block Model

# %%
from Girvan_Newman_stochastic_block_network import AssortativeMixing
mixed_network: AssortativeMixing = AssortativeMixing(seed=12345)
G = mixed_network.G

# %%
show_graph(G, title = "Girvan-Newman Assortative Graph")

# %%
partition: list[set[int]] = nx.community.louvain_communities(G,seed = 1234)
show_partitions(G, partition=partition, title = "Louvain communities of Girvan-Newman Stochastic Block Model:\n")

# %%
show_degree_vs_neighbor_degree(G, title_prefix = "Girvan-Newman Stochastic Block Model:\n")

# %%
#%load_ext autoreload
#%autoreload 2
#from partitioning_utilities import show_partitions_with_scaled_nodesize

group_ids: list[int] = list({G.nodes[node]["node_class"] for node in G.nodes()})
partition: list[set[int]] = []
for group_id in group_ids:
    group: set[int] = {node for node in G.nodes() if G.nodes[node]["node_class"] == group_id}
    partition.append(set(group))

show_partitions_with_scaled_nodesize(G, partition, title="Original classes of Girvan-Newman Stochastic Block Model:\n")

print(f"Number of edges = {len(G.edges())}")
# Out:
# Number of edges = 200

# %% [markdown]
# ---

# %% [markdown]
# Practice

# %%
#############
## Cell 10 ##
#############

M = np.array([[0.4, 0.02, 0.01, 0.03],
[0.02, 0.4, 0.03, 0.02],
[0.01, 0.03, 0.4, 0.01],
[0.03, 0.02, 0.01, 0.4]]) 

poisson_lambda = [5, 5, 5, 5]
# Try 
# poisson_lambda = [8, 4, 3, 2]
num_edges = 200
# Try
# num_edges = 300
# num_edges = 300

mixed_network: AssortativeMixing = AssortativeMixing(M, 
                                                    poisson_lambda, 
                                                    num_edges=num_edges,
                                                    seed=42)
G = mixed_network.G

print("Edges by type:")
for edge_type, count in mixed_network.edge_count_by_type.items():
    print(f"  {edge_type}: {count}")

print("Stubs by type")
for stub_type, count in mixed_network.stubs_per_class.items():
    print(f"  {stub_type}: {count}")

group_ids: list[int] = list({G.nodes[node]["node_class"] for node in G.nodes()})
partition: list[set[int]] = []
for group_id in group_ids:
    group: set[int] = {node for node in G.nodes() if G.nodes[node]["node_class"] == group_id}
    partition.append(set(group))

show_partitions(G, 
                partition, 
                title="Original classes of Girvan-Newman Stochastic Block Model\n")
# Out:
# Edges by type:
#   (0, 0): 44
#   (0, 1): 4
#   (0, 2): 1
#   (0, 3): 4
#   (1, 0): 2
#   (1, 1): 47
#   (1, 2): 3
#   (1, 3): 2
#   (2, 0): 0
#   (2, 1): 2
#   (2, 2): 41
#   (2, 3): 3
#   (3, 0): 3
#   (3, 1): 4
#   (3, 2): 0
#   (3, 3): 40
# Stubs by type
#   0: 102
#   1: 111
#   2: 91
#   3: 96

# %% [markdown]
# Show partitions with node size scaled by degree

# %%
show_partitions_with_scaled_nodesize(G, 
                                     partition, 
                                     title=f"Original classes of Girvan-Newman Stochastic Block Model:\nAssortativity = {np.round(nx.degree_assortativity_coefficient(G),2)}\n")

# %%
#############
## Cell 11 ##
#############

show_dendrogram(G, title="Dendrogram for Girvan-Newman", height_metric="max_cluster")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 #############
#       2 ## Cell 11 ##
#       3 #############
# ----> 5 show_dendrogram(G, title="Dendrogram for Girvan-Newman", height_metric="max_cluster")
#
# NameError: name 'show_dendrogram' is not defined
